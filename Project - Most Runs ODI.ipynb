# %%
# import pandas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# import csv file

df = pd.read_csv('/Users/otis/Desktop/most_runs_odi.csv')
df
# Out:
#                           Player       Span  Mat  Inns  NO   Runs    HS  \
# 0             SR Tendulkar (IND)  1989-2012  463   452  41  18426  200*
# 1    KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169
# 2                  V Kohli (IND)  2008-2023  292   280  44  13848   183
# 3           RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164
# 4           RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164
# ..                           ...        ...  ...   ...  ..    ...   ...
# 96                JP Duminy (SA)  2004-2019  199   179  40   5117  150*
# 97          PD Collingwood (ENG)  2001-2011  197   181  37   5092  120*
# 98               A Symonds (AUS)  1998-2009  198   161  33   5088   156
# 99       Abdul Razzaq (Asia/PAK)  1996-2011  265   228  57   5080   112
# 100             JC Buttler (ENG)  2012-2023  181   154  27   5022  162*
#
#        Ave       BF      SR 100  50   0    4s   6s
# 0    44.83  21368.0   86.23  49  96  20  2016  195
# ...

# %%
#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.describe()
# Out:
#               Mat        Inns    Not_Outs          Runs         Ave  \
# count  101.000000  101.000000  101.000000    101.000000  101.000000
# mean   241.980198  227.782178   29.158416   7703.970297   39.403762
# std     72.491238   68.777555   15.273986   2526.732924    6.511368
# min    117.000000  114.000000    3.000000   5022.000000   23.570000
# 25%    188.000000  178.000000   16.000000   5757.000000   35.050000
# 50%    232.000000  218.000000   28.000000   6951.000000   38.890000
# 75%    280.000000  258.000000   40.000000   8648.000000   43.400000
# max    463.000000  452.000000   84.000000  18426.000000   58.670000
#
#         Balls_Faced  Strike_Rate     Fifties       Ducks
# count     99.000000    99.000000  101.000000  101.000000
# mean    9532.020202    81.282929   46.247525   12.920792
# std     3154.793677    10.808271   16.049552    6.017779
# min     4288.000000    60.570000   23.000000    3.000000
# 25%     7306.500000    74.200000   35.000000    8.000000
# ...

# %%
# Rename columns

df = df.rename(columns = {'NO' : 'Not_Outs', 'HS' : 'Highest_Score', 'BF' : 'Balls_Faced', 
                          'SR' : 'Strike_Rate', '100' : 'Hundreds', '50' : 'Fifties',
                          '0' : 'Ducks', '4s' : 'Fours', '6s' : 'Sixes'})

# %%
df
# Out:
#                           Player       Span  Mat  Inns  Not_Outs   Runs  \
# 0             SR Tendulkar (IND)  1989-2012  463   452        41  18426
# 1    KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380        41  14234
# 2                  V Kohli (IND)  2008-2023  292   280        44  13848
# 3           RT Ponting (AUS/ICC)  1995-2012  375   365        39  13704
# 4           RT Ponting (AUS/ICC)  1995-2012  375   365        39  13704
# ..                           ...        ...  ...   ...       ...    ...
# 96                JP Duminy (SA)  2004-2019  199   179        40   5117
# 97          PD Collingwood (ENG)  2001-2011  197   181        37   5092
# 98               A Symonds (AUS)  1998-2009  198   161        33   5088
# 99       Abdul Razzaq (Asia/PAK)  1996-2011  265   228        57   5080
# 100             JC Buttler (ENG)  2012-2023  181   154        27   5022
#
#     Highest_Score    Ave  Balls_Faced  Strike_Rate Hundreds  Fifties  Ducks  \
# ...

# %%
# check for Null values

df.isnull().any()
# Out:
# Player           False
# Span             False
# Mat              False
# Inns             False
# Not_Outs         False
# Runs             False
# Highest_Score    False
# Ave              False
# Balls_Faced       True
# Strike_Rate       True
# Hundreds         False
# Fifties          False
# Ducks            False
# Fours            False
# Sixes            False
# dtype: bool

# %%
# viewing the rows with Null values

df[df['Balls_Faced'].isna()==1]
# Out:
#                Player       Span  Mat  Inns  Not_Outs   Runs Highest_Score  \
# 14   BC Lara (ICC/WI)  1990-2007  299   289        32  10405           169
# 22  Saeed Anwar (PAK)  1989-2003  247   244        19   8824           194
#
#       Ave  Balls_Faced  Strike_Rate Hundreds  Fifties  Ducks Fours Sixes
# 14  40.48          NaN          NaN       19       63     16  1042   133
# 22  39.21          NaN          NaN       20       43     15   938    97

# %%
# check for duplicates

df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# Length: 101, dtype: bool

# %%
# View duplicates

df[df['Player'].duplicated()==1]
# Out:
#                      Player       Span  Mat  Inns  Not_Outs   Runs  \
# 4      RT Ponting (AUS/ICC)  1995-2012  375   365        39  13704
# 19  AB de Villiers (Afr/SA)  2005-2018  228   218        39   9577
# 31  V Sehwag (Asia/ICC/IND)  1999-2013  251   245         9   8273
# 36      SP Fleming (ICC/NZ)  1994-2007  280   269        21   8037
#
#    Highest_Score    Ave  Balls_Faced  Strike_Rate Hundreds  Fifties  Ducks  \
# 4            164  42.03      17046.0        80.39       30       82     20
# 19           176  53.50       9473.0       101.09       25       53      7
# 31           219  35.05       7929.0       104.33       15       38     14
# 36          134*  32.40      11242.0        71.49        8       49     17
#
#    Fours Sixes
# 4   1231   162
# 19   840   204
# 31  1132   136
# 36   823    63

# %%
# delete duplicates

df = df.drop_duplicates()

# %%
# check if duplicates are removed

df[df['Player']=='RT Ponting (AUS/ICC)']
# Out:
#                  Player       Span  Mat  Inns  Not_Outs   Runs Highest_Score  \
# 3  RT Ponting (AUS/ICC)  1995-2012  375   365        39  13704           164
#
#      Ave  Balls_Faced  Strike_Rate Hundreds  Fifties  Ducks Fours Sixes
# 3  42.03      17046.0        80.39       30       82     20  1231   162

# %%
# spliting the column Span into Start Year and End Year

df["Span"].str.split(pat = '-')

# creating new columns

df['Start_Year'] = df['Span'].str.split(pat = '-').str[0].astype(int)
df['End_Year'] = df['Span'].str.split(pat = '-').str[1].astype(int)

# %%
# Remove comuln Span

df = df.drop(columns=['Span'])
df
# Out:
#                           Player  Mat  Inns  Not_Outs   Runs Highest_Score  \
# 0             SR Tendulkar (IND)  463   452        41  18426          200*
# 1    KC Sangakkara (Asia/ICC/SL)  404   380        41  14234           169
# 2                  V Kohli (IND)  292   280        44  13848           183
# 3           RT Ponting (AUS/ICC)  375   365        39  13704           164
# 5        ST Jayasuriya (Asia/SL)  445   433        18  13430           189
# ..                           ...  ...   ...       ...    ...           ...
# 96                JP Duminy (SA)  199   179        40   5117          150*
# 97          PD Collingwood (ENG)  197   181        37   5092          120*
# 98               A Symonds (AUS)  198   161        33   5088           156
# 99       Abdul Razzaq (Asia/PAK)  265   228        57   5080           112
# 100             JC Buttler (ENG)  181   154        27   5022          162*
#
# ...

# %%
# spliting team names from Player column

df['Teams'] = df['Player'].str.split(" \(").str[1]
df['Player'] = df['Player'].str.split(" \(").str[0]

# %%
# removing ")" at the end of Teams column

df['Teams'] = df['Teams'].str[:-1]

# %%
df
# Out:
#              Player  Mat  Inns  Not_Outs   Runs Highest_Score    Ave  \
# 0      SR Tendulkar  463   452        41  18426          200*  44.83
# 1     KC Sangakkara  404   380        41  14234           169  41.98
# 2           V Kohli  292   280        44  13848           183  58.67
# 3        RT Ponting  375   365        39  13704           164  42.03
# 5     ST Jayasuriya  445   433        18  13430           189  32.36
# ..              ...  ...   ...       ...    ...           ...    ...
# 96        JP Duminy  199   179        40   5117          150*  36.81
# 97   PD Collingwood  197   181        37   5092          120*  35.36
# 98        A Symonds  198   161        33   5088           156  39.75
# 99     Abdul Razzaq  265   228        57   5080           112  29.70
# 100      JC Buttler  181   154        27   5022          162*  39.54
#
#      Balls_Faced  Strike_Rate Hundreds  Fifties  Ducks Fours Sixes  \
# 0        21368.0        86.23       49       96     20  2016   195
# ...

# %%
# check datatypes

df.dtypes
# Out:
# Player            object
# Span              object
# Mat                int64
# Inns               int64
# Not_Outs           int64
# Runs               int64
# Highest_Score     object
# Ave              float64
# Balls_Faced      float64
# Strike_Rate      float64
# Hundreds          object
# Fifties            int64
# Ducks              int64
# Fours             object
# Sixes             object
# Start_Year         int64
# End_Year           int64
# Teams             object
# dtype: object

# %%
# change datatypes

# %%
# new column where if the Highest Score is a Not Out 1 else 0

df['HS_Not_Out'] = df['Highest_Score'].str.contains(r'\*').astype(int)

# %%
# remove * from Highest Score

df['Highest_Score'] = df['Highest_Score'].str.split(pat = '*').str[0].astype(int)

# %%
# change datatype for Start_Year, End_Year

df = df.astype({'Start_Year': 'int', 'End_Year':'int'})

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not_Outs           int64
# Runs               int64
# Highest_Score      int64
# Ave              float64
# Balls_Faced      float64
# Strike_Rate      float64
# Hundreds           int64
# Fifties            int64
# Ducks              int64
# Fours             object
# Sixes             object
# Start_Year         int64
# End_Year           int64
# Teams             object
# HS_Not_Out         int64
# dtype: object

# %%
df['Fours'].unique()
# Out:
# array(['2016', '1385', '1294', '1231', '1500', '1119', '971', '911',
#        '1122', '950', '826', '994', '1128', '1042', '1111', '785', '1162',
#        '840', '622+', '712+', '938', '722', '908', '768+', '713', '734',
#        '651', '925', '1132', '822', '930', '730', '823', '665', '617',
#        '654', '699', '530', '603', '523+', '445+', '750', '578', '514+',
#        '720', '788', '798', '733', '450', '622', '659', '842', '532+',
#        '771', '600+', '599', '664', '557+', '531+', '500', '520', '541+',
#        '636', '577', '380+', '494', '392', '468', '469+', '480', '409',
#        '570', '613', '585', '476', '526', '366', '495', '486', '383',
#        '525', '532', '406', '441', '561', '427+', '414', '331+', '470+',
#        '342', '347', '365', '449', '382', '407'], dtype=object)

# %%
# change datatype of Hundreds

df['Hundreds'] = np.where(df['Hundreds'] == '-', 0, df['Hundreds']).astype(int)

# %%
# change datatype of Fours and Sixes

df['Fours'] = df['Fours'].str.split(pat = '+').str[0].astype(int)
df['Sixes'] = df['Sixes'].str.split(pat = '+').str[0].astype(int)

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not_Outs           int64
# Runs               int64
# Highest_Score      int64
# Ave              float64
# Balls_Faced      float64
# Strike_Rate      float64
# Hundreds           int64
# Fifties            int64
# Ducks              int64
# Fours              int64
# Sixes              int64
# Start_Year         int64
# End_Year           int64
# Teams             object
# HS_Not_Out         int64
# dtype: object

# %%
# create new columnn Career_Length

df['Career_Length'] = df['End_Year'] - df['Start_Year']

# %%
df
# Out:
#              Player  Mat  Inns  Not_Outs   Runs  Highest_Score    Ave  \
# 0      SR Tendulkar  463   452        41  18426            200  44.83
# 1     KC Sangakkara  404   380        41  14234            169  41.98
# 2           V Kohli  292   280        44  13848            183  58.67
# 3        RT Ponting  375   365        39  13704            164  42.03
# 5     ST Jayasuriya  445   433        18  13430            189  32.36
# ..              ...  ...   ...       ...    ...            ...    ...
# 96        JP Duminy  199   179        40   5117            150  36.81
# 97   PD Collingwood  197   181        37   5092            120  35.36
# 98        A Symonds  198   161        33   5088            156  39.75
# 99     Abdul Razzaq  265   228        57   5080            112  29.70
# 100      JC Buttler  181   154        27   5022            162  39.54
#
#      Balls_Faced  Strike_Rate  Hundreds  Fifties  Ducks  Fours  Sixes  \
# ...

# %%
# 1. What is the distribution of player averages?
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'Not_Outs', 'Runs', 'Highest_Score',
#        'Ave', 'Balls_Faced', 'Strike_Rate', 'Hundreds', 'Fifties', 'Ducks',
#        'Fours', 'Sixes', 'Start_Year', 'End_Year', 'Teams', 'HS_Not_Out',
#        'Career_Length'],
#       dtype='object')

# %%
# Plotting the distribution of player averages
plt.figure(figsize=(10, 6))
sns.histplot(df['Ave'], bins=10, kde=True, color='skyblue')
plt.title('Distribution of Player Averages')
plt.xlabel('Batting Average')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 2. How does the number of matches played correlate with the player's average?
# Out:
#              Player       Span  Mat  Inns  Not_Outs   Runs  Highest_Score  \
# 0      SR Tendulkar  1989-2012  463   452        41  18426            200
# 1     KC Sangakkara  2000-2015  404   380        41  14234            169
# 2           V Kohli  2008-2023  292   280        44  13848            183
# 3        RT Ponting  1995-2012  375   365        39  13704            164
# 5     ST Jayasuriya  1989-2011  445   433        18  13430            189
# ..              ...        ...  ...   ...       ...    ...            ...
# 96        JP Duminy  2004-2019  199   179        40   5117            150
# 97   PD Collingwood  2001-2011  197   181        37   5092            120
# 98        A Symonds  1998-2009  198   161        33   5088            156
# 99     Abdul Razzaq  1996-2011  265   228        57   5080            112
# 100      JC Buttler  2012-2023  181   154        27   5022            162
#
#        Ave  Balls_Faced  Strike_Rate  Hundreds  Fifties  Ducks  Fours  Sixes  \
# ...

# %%
# Scatter plot of Matches vs. Batting Average
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Mat', y='Ave', data=df, hue='Player', palette='viridis', s=100)
plt.title('Correlation between Matches Played and Batting Average')
plt.xlabel('Matches Played')
plt.ylabel('Batting Average')
plt.grid(True)
plt.show()

# %%
# 4. Which players have the highest number of centuries and strike rates?

# %%
# Top players based on Centuries and Strike Rate
top_centuries = df.sort_values(by='Hundreds', ascending=False).head(5)
top_strike_rate = df.sort_values(by='Strike_Rate', ascending=False).head(5)

# Plotting Centuries
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.barplot(x='Player', y='Hundreds', data=top_centuries, palette='magma')
plt.title('Top Players by Centuries')
plt.xlabel('Player')
plt.ylabel('Centuries')

# Plotting Strike Rate
plt.subplot(1, 2, 2)
sns.barplot(x='Player', y='Strike_Rate', data=top_strike_rate, palette='coolwarm')
plt.title('Top Players by Strike Rate')
plt.xlabel('Player')
plt.ylabel('Strike Rate')

plt.tight_layout()
plt.show()

# %%
# 5. What is the relationship between the number of 'Not Outs' and Batting Average?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Not_Outs', y='Ave', data=df, hue='Player', palette='Spectral', s=100)
plt.title('Impact of Not Outs on Batting Average')
plt.xlabel('Not Outs')
plt.ylabel('Batting Average')
plt.grid(True)
plt.show()

# %%
# 7. What is the relationship between the number of balls faced and runs scored?

# %%
# Scatter plot of Balls Faced vs. Runs
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Balls_Faced', y='Runs', data=df, hue='Player', palette='Set1', s=100)
plt.title('Relationship between Balls Faced and Runs Scored')
plt.xlabel('Balls Faced')
plt.ylabel('Runs Scored')
plt.grid(True)
plt.show()

# %%
# 9. Which teams have the most representation in the dataset?

# %%
df["Teams"].unique()
# Out:
# array(['IND', 'Asia/ICC/SL', 'AUS/ICC', 'Asia/SL', 'Asia/PAK',
#        'Afr/ICC/SA', 'Asia/IND', 'Asia/ICC/IND', 'ICC/WI', 'SL', 'Afr/SA',
#        'PAK', 'WI', 'NZ', 'AUS', 'BAN', 'SA', 'Asia/ICC/PAK', 'ICC/NZ',
#        'ENG/IRE', 'ZIM', 'ENG', 'IRE'], dtype=object)

# %%
# List of team codes we are interested in
main_teams = ['IND', 'SL', 'AUS', 'PAK', 'SA', 'WI', 'NZ', 'BAN', 'ENG', 'IRE', 'ZIM']

# Function to determine the main team from the string
def get_main_team(team):
    for code in main_teams:
        if code in team:  # Check if the main team code is a substring
            return code
    return team  # Return the original value if no match is found

# Apply the function to create the 'Main_Team' column
df['Main_Team'] = df['Teams'].apply(get_main_team)
# Out:
# array(['IND', 'SL', 'AUS', 'PAK', 'SA', 'WI', 'NZ', 'BAN', 'ENG', 'ZIM',
#        'IRE'], dtype=object)

# %%
# Counting team representation
team_counts = df['Main_Team'].value_counts()

# Bar plot of team representation
plt.figure(figsize=(8, 6))
sns.barplot(x=team_counts.index, y=team_counts.values, palette='Paired')
plt.title('Team Representation in the Dataset')
plt.xlabel('Main_Team')
plt.ylabel('Number of Players')
plt.xticks(rotation=45)
plt.show()

# %%
df[df['Teams'].str.contains('PAK')]['Teams'].value_counts().sum()
# Out:
# 14

# %%
# Filter players with more than 8000 runs
df_8000_runs = df[df['Runs'] > 8000]

# Counting team representation for players with more than 8000 runs
team_counts_8000 = df_8000_runs['Main_Team'].value_counts()

# Bar plot of team representation for players with more than 8000 runs
plt.figure(figsize=(10, 6))
sns.barplot(x=team_counts_8000.index, y=team_counts_8000.values, palette='Paired')
plt.title('Team Representation for Players with More Than 8,000 Runs')
plt.xlabel('Main Team')
plt.ylabel('Number of Players')
plt.xticks(rotation=45)
plt.show()

# %%
# 10. Which players have the highest proportion of 'Fours' and 'Sixes' compared to their total runs?

# %%
# Calculating proportion of Fours and Sixes
df['Fours_Proportion'] = (df['Fours'] * 4) / df['Runs']
df['Sixes_Proportion'] = (df['Sixes'] * 6) / df['Runs']

# Selecting top 10 players based on Fours_Proportion
top_10_fours = df.nlargest(10, 'Fours_Proportion')

# Selecting top 10 players based on Sixes_Proportion
top_10_sixes = df.nlargest(10, 'Sixes_Proportion')

# Plotting Fours and Sixes Proportion for Top 10 Players
plt.figure(figsize=(14, 7))

# Plot for Fours Proportion
plt.subplot(1, 2, 1)
sns.barplot(x='Player', y='Fours_Proportion', data=top_10_fours, palette='BuGn')
plt.title('Top 10 Players: Proportion of Runs from Fours')
plt.xlabel('Player')
plt.ylabel('Proportion of Total Runs')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees

# Plot for Sixes Proportion
plt.subplot(1, 2, 2)
sns.barplot(x='Player', y='Sixes_Proportion', data=top_10_sixes, palette='OrRd')
plt.title('Top 10 Players: Proportion of Runs from Sixes')
plt.xlabel('Player')
plt.ylabel('Proportion of Total Runs')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees

plt.tight_layout()
plt.show()

# %%
# 12. How does the number of ducks correlate with player consistency?

# %%
# Scatter plot of Ducks vs. Batting Average
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Ducks', y='Ave', data=df, hue='Player', palette='cool', s=100)
plt.title('Correlation between Ducks and Batting Average')
plt.xlabel('Number of Ducks')
plt.ylabel('Batting Average')
plt.grid(True)
plt.show()

# %%
# 15. Which team has the highest total runs scored by their players?

# %%
# Aggregating runs by Main_Team
team_runs = df.groupby('Main_Team')['Runs'].sum().reset_index()

# Sorting teams by total runs for better visualization
team_runs = team_runs.sort_values(by='Runs', ascending=False)

# Plotting total runs by Main_Team
plt.figure(figsize=(10, 6))
sns.barplot(x='Main_Team', y='Runs', data=team_runs, palette='viridis')
plt.title('Total Runs by Main Team')
plt.xlabel('Main Team')
plt.ylabel('Total Runs')
plt.xticks(rotation=45)
plt.show()

# %%
# 17. How does the number of fifties relate to the number of centuries?

# %%
# Scatter plot of Fifties vs. Centuries
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Fifties', y='Hundreds', data=df, hue='Player', palette='viridis', s=100)
plt.title('Relationship between Fifties and Centuries')
plt.xlabel('Number of Fifties')
plt.ylabel('Number of Centuries')
plt.grid(True)
plt.show()

# %%
# Calculate runs from Fours and Sixes
df['Runs_from_Fours'] = df['Fours'] * 4
df['Runs_from_Sixes'] = df['Sixes'] * 6

# Identify top 10 players for each category
top_10_fours = df.nlargest(10, 'Runs_from_Fours')
top_10_sixes = df.nlargest(10, 'Runs_from_Sixes')

# Plotting
plt.figure(figsize=(18, 6))

# Plot for Runs from Fours
plt.subplot(1, 2, 1)
sns.barplot(x='Runs_from_Fours', y='Player', data=top_10_fours, palette='Blues_d')
plt.title('Top 10 Players: Runs from Fours')
plt.xlabel('Runs from Fours')
plt.ylabel('Player')

# Plot for Runs from Sixes
plt.subplot(1, 2, 2)
sns.barplot(x='Runs_from_Sixes', y='Player', data=top_10_sixes, palette='Reds_d')
plt.title('Top 10 Players: Runs from Sixes')
plt.xlabel('Runs from Sixes')
plt.ylabel('Player')

plt.tight_layout()
plt.show()

# %%
# most ryns from boundaries

# %%
# Calculate runs from Fours and Sixes
df['Runs_from_Fours'] = df['Fours'] * 4
df['Runs_from_Sixes'] = df['Sixes'] * 6

# Calculate total runs from Boundaries
df['Runs_from_Boundaries'] = df['Runs_from_Fours'] + df['Runs_from_Sixes']

# Identify top 10 players for combined runs from Fours and Sixes
top_10_boundaries = df.nlargest(10, 'Runs_from_Boundaries')

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x='Runs_from_Boundaries', y='Player', data=top_10_boundaries, palette='viridis')
plt.title('Top 10 Players: Runs from Fours and Sixes Combined')
plt.xlabel('Runs from Boundaries (Fours & Sixes)')
plt.ylabel('Player')
plt.show()

# %%
# most runs excluding boundaries

# %%
# Calculate total runs from Boundaries
df['Runs_from_Fours'] = df['Fours'] * 4
df['Runs_from_Sixes'] = df['Sixes'] * 6
df['Runs_from_Boundaries'] = df['Runs_from_Fours'] + df['Runs_from_Sixes']

# Calculate runs excluding boundaries
df['Runs_excluding_Boundaries'] = df['Runs'] - df['Runs_from_Boundaries']

# Identify top 10 players for runs excluding boundaries
top_10_excluding_boundaries = df.nlargest(10, 'Runs_excluding_Boundaries')

# Plotting
plt.figure(figsize=(12 bxcluding_Boundaries', y='Player', data=top_10_excluding_boundaries, palette='cividis')
plt.title('Top 10 Players: Runs Excluding Boundaries')
plt.xlabel('Runs Excluding Boundaries')
plt.ylabel('Player')
plt.show()
# Out:
#   Cell In[86], line 13
#     plt.figure(figsize=(12 bxcluding_Boundaries', y='Player', data=top_10_excluding_boundaries, palette='cividis')
#                                                                                                                 ^
# SyntaxError: unterminated string literal (detected at line 13)

# %%
# 18. What is the frequency distribution of career spans?

# %%
# Histogram of Career Lengths
plt.figure(figsize=(10, 6))
sns.histplot(df['Career_Length'], bins=10, kde=True, color='darkcyan')
plt.title('Distribution of Career Lengths')
plt.xlabel('Career Length (Years)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 19 Which players have the highest Strike Rate with low average?

# %%
# Filtering players with high Strike Rate and low Average
aggressive_players = df[(df['Strike_Rate'] > 85) & (df['Ave'] < 40)]

# Sorting aggressive players by Strike Rate in descending order
aggressive_players = aggressive_players.sort_values(by='Strike_Rate', ascending=False)

# Bar plot for Aggressive Players
plt.figure(figsize=(10, 6))
sns.barplot(x='Player', y='Strike_Rate', data=aggressive_players, palette='plasma')
plt.title('Players with High Strike Rate and Average Lower Than 40')
plt.xlabel('Player')
plt.ylabel('Strike Rate')
plt.xticks(rotation=45)
plt.show()

# %%
# Box plot of Runs by Team
plt.figure(figsize=(10, 6))
sns.boxplot(x='Main_Team', y='Runs', data=df, palette='Set2')
plt.title('Distribution of Runs by Team')
plt.xlabel('Team')
plt.ylabel('Runs')
plt.show()

# %%
# Violin Plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='Runs', data=df, palette='muted')
plt.title('Violin Plot of Runs Distribution')
plt.xlabel('Runs')
plt.show()

# %%
# Aggregating runs by team
team_runs = df.groupby('Main_Team')['Runs'].sum().reset_index()

# Treemap with annotations
fig = px.treemap(team_runs, path=['Main_Team'], values='Runs', title='Treemap of Runs by Team')

# Adding annotations
fig.update_traces(
    textinfo="label+value",  # Display both label and value
    textfont_size=15,        # Font size of the text
    textposition="middle center"    # Position of text inside the treemap
)

fig.show()
# Out:
# <div>                            <div id="86b664e9-ab14-44ef-8673-8c4be02c646d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86b664e9-ab14-44ef-8673-8c4be02c646d")) {                    Plotly.newPlot(                        "86b664e9-ab14-44ef-8673-8c4be02c646d",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Runs=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["AUS","BAN","ENG","IND","IRE","NZ","PAK","SA","SL","WI","ZIM"],"labels":["AUS","BAN","ENG","IND","IRE","NZ","PAK","SA","SL","WI","ZIM"],"name":"","parents":["","","","","","","","","","",""],"values":[118391,29105,29753,125365,5700,43973,102631,80044,93902,78762,30884],"type":"treemap","textfont":{
# ...
